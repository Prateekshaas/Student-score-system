# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'C:\Users\prate\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df = pd.read_csv("students.csv")
df
# Out:
#    Student ID  Hours_Studied  Marks
# 0           1              1     20
# 1           2              2     35
# 2           3              3     50
# 3           4              4     65
# 4           5              5     80
# 5           6              6     90
# 6           7              7     95

# %%
df.sort_values(by="Marks", ascending=False)
# Out:
#    Student ID  Hours_Studied  Marks
# 6           7              7     95
# 5           6              6     90
# 4           5              5     80
# 3           4              4     65
# 2           3              3     50
# 1           2              2     35
# 0           1              1     20

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.5-cp310-cp310-win_amd64.whl (8.1 MB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.2.6)
# Collecting pillow>=8
#   Downloading pillow-11.3.0-cp310-cp310-win_amd64.whl (7.0 MB)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (25.0)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.59.0-cp310-cp310-win_amd64.whl (2.3 MB)
# Requirement already satisfied: six>=1.5 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.59.0 kiwisolver-1.4.8 matplotlib-3.10.5 pillow-11.3.0 pyparsing-3.2.3
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'C:\Users\prate\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Hours_Studied'], df['Marks'])
plt.title("Hours vs Marks")
plt.xlabel("Hours Studied")
plt.ylabel("Marks Scored")
plt.show()

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from sklearn) (1.7.1)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (3.6.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\prate\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (2.2.6)
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'C:\Users\prate\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['Hours_Studied']]

# %%
Y = df['Marks']

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
print(f"Hours Studied: 8 -> Marks Scored: {model.predict([[8]])} ")
# Out:
# Hours Studied: 8 -> Marks Scored: [114.28571429]
# C:\Users\prate\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(f"Hours Studied: 9 -> Marks Scored: {model.predict([[9]])} ")
# Out:
# Hours Studied: 9 -> Marks Scored: [127.32142857]
# C:\Users\prate\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
